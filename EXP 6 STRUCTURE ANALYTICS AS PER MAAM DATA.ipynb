# %%
import pandas as pd
import networkx as nx

# %%
pip install fin-news
# Out:
# Collecting fin-news
#   Downloading fin_news-0.1.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from fin-news) (2.31.0)
# Collecting fake-useragent==0.1.11 (from fin-news)
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->fin-news) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->fin-news) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->fin-news) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.24.0->fin-news) (2024.2.2)
# Building wheels for collected packages: fake-useragent
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13482 sha256=6484bf6935009c315c1a61eff530f3ff7a6865c16b10e382325f584e77886766
#   Stored in directory: /root/.cache/pip/wheels/ad/4f/20/1880f6cbdf5e12b5fa9635d072735ea0842db7346939891812
# Successfully built fake-useragent
# Installing collected packages: fake-useragent, fin-news
# Successfully installed fake-useragent-0.1.11 fin-news-0.1.2

# %%
pip install network
# Out:
# Collecting network
#   Downloading network-0.1.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: network
#   Building wheel for network (setup.py) ... done
#   Created wheel for network: filename=network-0.1-py3-none-any.whl size=3139 sha256=801138dd2f111c7890096a56efba1516e1a3acdea2b3fe0317fb7d7193dfcfb1
#   Stored in directory: /root/.cache/pip/wheels/25/97/b1/563d3a70ed8f588bf9cf448f079024a9751b54d15a0ce3d46b
# Successfully built network
# Installing collected packages: network
# Successfully installed network-0.1

# %%
import networkx
G=networkx.Graph()
G.add_node('A')
G.add_node('B')
G.add_node('C')
G.add_node('D')
G.add_node('E')
G.add_node('F')
G.add_node('G')
G.add_node('H')

# %%
G.add_edge('A','B')
G.add_edge('B','A')
G.add_edge('B','C')
G.add_edge('C','B')
G.add_edge('B','D')
G.add_edge('D','B')
G.add_edge('C','E')
G.add_edge('E','C')
G.add_edge('E','D')
G.add_edge('D','E')
G.add_edge('E','H')
G.add_edge('H','E')
G.add_edge('E','G')
G.add_edge('G','E')
G.add_edge('E','F')
G.add_edge('F','E')
G.add_edge('H','G')
G.add_edge('G','H')
G.add_edge('D','G')
G.add_edge('G','D')

# %%
G.edges()
# Out:
# EdgeView([('A', 'B'), ('B', 'C'), ('B', 'D'), ('C', 'E'), ('D', 'E'), ('D', 'G'), ('E', 'H'), ('E', 'G'), ('E', 'F'), ('G', 'H')])

# %%
nx.draw(G,with_labels=1)

# %%
nx.degree_centrality(G)
# Out:
# {'A': 0.14285714285714285,
#  'B': 0.42857142857142855,
#  'C': 0.2857142857142857,
#  'D': 0.42857142857142855,
#  'E': 0.7142857142857142,
#  'F': 0.14285714285714285,
#  'G': 0.42857142857142855,
#  'H': 0.2857142857142857}

# %%
import matplotlib.pyplot as plt
import networkx as nx
G=nx.Graph()
G.add_nodes_from(['A','B','C','D','E','F','G','H'])
G.add_edges_from([('A', 'B'), ('B', 'C'), ('B', 'D'), ('C', 'E'), ('D', 'E'), ('D', 'G'), ('E', 'H'), ('E', 'G'), ('E', 'F'), ('G', 'H')])

# %%
nx.draw(G,with_labels=True,node_color="orange",node_size=3000,font_color="White")
plt.margins(0.2)
plt.show()

# %%
nx.degree_centrality(G)
# Out:
# {'A': 0.14285714285714285,
#  'B': 0.42857142857142855,
#  'C': 0.2857142857142857,
#  'D': 0.42857142857142855,
#  'E': 0.7142857142857142,
#  'F': 0.14285714285714285,
#  'G': 0.42857142857142855,
#  'H': 0.2857142857142857}

# %%
nx.degree(G)
# Out:
# DegreeView({'A': 1, 'B': 3, 'C': 2, 'D': 3, 'E': 5, 'F': 1, 'G': 3, 'H': 2})

# %%
m_influential=nx.degree_centrality(G)
nx.eigenvector_centrality(G)
# Out:
# {'A': 0.0892314798120002,
#  'B': 0.2660740286403953,
#  'C': 0.27754341242731234,
#  'D': 0.4266201277775895,
#  'E': 0.5615233897735086,
#  'F': 0.18831193261533638,
#  'G': 0.4445292724700449,
#  'H': 0.33738864796561363}

# %%
nx.betweenness_centrality(G)
# Out:
# {'A': 0.0,
#  'B': 0.30952380952380953,
#  'C': 0.12698412698412698,
#  'D': 0.25396825396825395,
#  'E': 0.492063492063492,
#  'F': 0.0,
#  'G': 0.055555555555555546,
#  'H': 0.0}

# %%
list(nx.find_cliques(G))
# Out:
# [['B', 'C'],
#  ['B', 'D'],
#  ['B', 'A'],
#  ['E', 'C'],
#  ['E', 'F'],
#  ['E', 'G', 'D'],
#  ['E', 'G', 'H']]

# %%
hub_ego = nx.ego_graph(G, 'E')
pos = nx.spring_layout(G)
nx.draw(hub_ego, pos, node_color="lavender", node_size=800, with_labels=True)
nx.draw_networkx_nodes(hub_ego, pos, nodelist=['E'], node_color='red', node_size=800)
plt.show()

# %%
nx.density(G)
# Out:
# 0.35714285714285715

# %%
nx.has_bridges(G)
# Out:
# True

# %%
nx.closeness_centrality(G)
# Out:
# {'A': 0.3684210526315789,
#  'B': 0.5384615384615384,
#  'C': 0.5833333333333334,
#  'D': 0.6363636363636364,
#  'E': 0.7,
#  'F': 0.4375,
#  'G': 0.5833333333333334,
#  'H': 0.4666666666666667}
