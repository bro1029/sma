# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("sma.csv")

print(data.head(20))
print(data.info())
# Out:
#     id                     author  \
# 0    1          @sherylhowell3061
# 1    2                 @bsnsj4659
# 2    3           @ThereRobloxgirl
# 3    4             @asphyxia35p21
# 4    5             @asphyxia35p21
# 5    6              @KanarkNights
# 6    7          @TheOneTrueNoName
# 7    8           @imrimenashe5161
# 8    9             @MonicovennSom
# 9   10                 @Freyja369
# 10  11    @anes-for-entertainment
# 11  12                      @DJ0o
# 12  13  @MichaelJohnBesanez-br4gh
# 13  14                @EthanMalde
# 14  15           @user-ew6ks4mu4u
# 15  16      @YORIICHI_TSUGIKUNII7
# 16  17                @sangeetakr
# 17  18           @yasin_arafat_77
# 18  19     @yesseniahernandez9102
# 19  20                @MultiMacel
#
#                                           description  \
# 0   I wish this anime never ends until muzan is de...
# 1   Boku no hero academy : where is my Intellectua...
# 2                              I just got crunchyroll
# 3   When I heard Gyomei\'s voice, It\'s always Gin...
# 4                                      Gintoki?!!!!!!
# 5                    They done made tanjiro like asta
# 6   Just finished the movie, I would\'ve been mad ...
# 7                                                Why?
# 8                         Bro this is gonna be fire 🔥
# 9   THE SONG IS MY FAVORITE THING EVERRRR!!!! 💕💕💕💕...
# 10  This should\'ve been made into a movie This ar...
# 11                             Tengen got dripped out
# 12                                    The OSt men 🔥🔥🔥
# 13                                          L trailer
# 14              When season 4 is come 😅 I can\'t wait
# 15                                  Namu Amida Butsu.
# 16            Its realising on my birthday YEAHHHHHHH
# 17                                                 👍👍
# 18                       Yaaaaaaaaaaaaaaaaaaaaaaaaaa🎉
# 19                                        yey its out
#
#                                                  guid                 to  \
# 0                          UgzLbN7zivs-_vc5hOB4AaABAg                NaN
# 1                          UgxK7GcRTkmmVyXhoX94AaABAg                NaN
# 2                          UgxJDwUKB-DV4-FSsvp4AaABAg                NaN
# 3                          Ugx6roKZSFI2--GNoj14AaABAg                NaN
# 4                          Ugw07D17qa51KT9djeJ4AaABAg                NaN
# 5                          UgykI68cHg-Wt7jw_jl4AaABAg                NaN
# 6                          UgyuEsgMhm-cT_U0U_t4AaABAg                NaN
# 7   UgyuEsgMhm-cT_U0U_t4AaABAg.A2kyaMXieaVA2ly6twfWjm  @TheOneTrueNoName
# 8                          UgxY5w-t86aujwVn5ih4AaABAg                NaN
# 9                          UgzCKO5hq7tD_R5nq0p4AaABAg                NaN
# 10                         UgwLWRoVrTEu2gS15Fl4AaABAg                NaN
# 11                         UgyAocIvCCOmneP0DHV4AaABAg                NaN
# 12                         Ugx11Q1YQvWFM5A95hN4AaABAg                NaN
# 13                         UgzjUgZxWDbD673V2Zx4AaABAg                NaN
# 14                         UgwionjxPdq8r7ZgONZ4AaABAg                NaN
# 15                         Ugy86o5Rlf-01KjTKUF4AaABAg                NaN
# 16                         UgzamKF-IfMjygdaOWl4AaABAg                NaN
# 17                         UgwRp3o46WpDn5hAWcx4AaABAg                NaN
# 18                         UgzecdCCSXSjYyiaovt4AaABAg                NaN
# 19                         UgxGsJ1NdFiUJAt2Z7J4AaABAg                NaN
#
#     likecount                                               link  \
# 0           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 1           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 2           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 3           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 4           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 5           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 6           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 7           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 8           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 9           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 10          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 11          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 12          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 13          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 14          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 15          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 16          1  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 17          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 18          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 19          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
#
#                 pubdate  replycount  \
# 0   2024-04-28 11:01:27           0
# 1   2024-04-28 10:16:30           0
# 2   2024-04-28 08:06:03           0
# 3   2024-04-28 06:35:10           0
# 4   2024-04-28 06:33:53           0
# 5   2024-04-27 23:35:51           0
# 6   2024-04-27 22:32:24           1
# 7   2024-04-28 07:47:29           0
# 8   2024-04-27 19:02:56           0
# 9   2024-04-26 18:47:51           0
# 10  2024-04-26 17:53:02           0
# 11  2024-04-26 17:26:16           0
# 12  2024-04-26 09:43:02           0
# 13  2024-04-26 06:09:28           0
# 14  2024-04-26 06:02:40           0
# 15  2024-04-26 04:21:07           0
# 16  2024-04-26 01:07:34           0
# 17  2024-04-26 00:42:43           0
# 18  2024-04-25 23:44:50           0
# 19  2024-04-25 23:08:37           0
#
#                                                 title  \
# 0   I wish this anime never ends until muzan is de...
# 1   Boku no hero academy : where is my Intellectua...
# 2                              I just got crunchyroll
# 3   When I heard Gyomei\'s voice, It\'s always Gin...
# 4                                      Gintoki?!!!!!!
# 5                    They done made tanjiro like asta
# 6   Just finished the movie, I would\'ve been mad ...
# 7                                                Why?
# 8                         Bro this is gonna be fire 🔥
# 9   THE SONG IS MY FAVORITE THING EVERRRR!!!! 💕💕💕💕...
# 10  This should\'ve been made into a movie This ar...
# 11                             Tengen got dripped out
# 12                                    The OSt men 🔥🔥🔥
# 13                                          L trailer
# 14              When season 4 is come 😅 I can\'t wait
# 15                                  Namu Amida Butsu.
# 16            Its realising on my birthday YEAHHHHHHH
# 17                                                 👍👍
# 18                       Yaaaaaaaaaaaaaaaaaaaaaaaaaa🎉
# 19                                        yey its out
#
#                                     authorChannelUrl  Unnamed: 11
# 0           http://www.youtube.com/@sherylhowell3061          NaN
# 1                  http://www.youtube.com/@bsnsj4659          NaN
# 2            http://www.youtube.com/@ThereRobloxgirl          NaN
# 3              http://www.youtube.com/@asphyxia35p21          NaN
# 4              http://www.youtube.com/@asphyxia35p21          NaN
# 5               http://www.youtube.com/@KanarkNights          NaN
# 6           http://www.youtube.com/@TheOneTrueNoName          NaN
# 7            http://www.youtube.com/@imrimenashe5161          NaN
# 8              http://www.youtube.com/@MonicovennSom          NaN
# 9                  http://www.youtube.com/@Freyja369          NaN
# 10    http://www.youtube.com/@anes-for-entertainment          NaN
# 11                      http://www.youtube.com/@DJ0o          NaN
# 12  http://www.youtube.com/@MichaelJohnBesanez-br4gh          NaN
# 13                http://www.youtube.com/@EthanMalde          NaN
# 14           http://www.youtube.com/@user-ew6ks4mu4u          NaN
# 15      http://www.youtube.com/@YORIICHI_TSUGIKUNII7          NaN
# 16                http://www.youtube.com/@sangeetakr          NaN
# 17           http://www.youtube.com/@yasin_arafat_77          NaN
# 18     http://www.youtube.com/@yesseniahernandez9102          NaN
# 19                http://www.youtube.com/@MultiMacel          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2404 non-null   int64
#  1   author            2403 non-null   object
#  2   description       2404 non-null   object
#  3   guid              2404 non-null   object
#  4   to                454 non-null    object
#  5   likecount         2404 non-null   int64
#  6   link              2404 non-null   object
#  7   pubdate           2404 non-null   object
#  8   replycount        2404 non-null   int64
#  9   title             2404 non-null   object
#  10  authorChannelUrl  2404 non-null   object
#  11  Unnamed: 11       0 non-null      float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 225.5+ KB
# None

# %%
data.drop_duplicates(inplace=True)

# %%
print(data.head(20))
print(data.info())
# Out:
#     id                     author  \
# 0    1          @sherylhowell3061
# 1    2                 @bsnsj4659
# 2    3           @ThereRobloxgirl
# 3    4             @asphyxia35p21
# 4    5             @asphyxia35p21
# 5    6              @KanarkNights
# 6    7          @TheOneTrueNoName
# 7    8           @imrimenashe5161
# 8    9             @MonicovennSom
# 9   10                 @Freyja369
# 10  11    @anes-for-entertainment
# 11  12                      @DJ0o
# 12  13  @MichaelJohnBesanez-br4gh
# 13  14                @EthanMalde
# 14  15           @user-ew6ks4mu4u
# 15  16      @YORIICHI_TSUGIKUNII7
# 16  17                @sangeetakr
# 17  18           @yasin_arafat_77
# 18  19     @yesseniahernandez9102
# 19  20                @MultiMacel
#
#                                           description  \
# 0   I wish this anime never ends until muzan is de...
# 1   Boku no hero academy : where is my Intellectua...
# 2                              I just got crunchyroll
# 3   When I heard Gyomei\'s voice, It\'s always Gin...
# 4                                      Gintoki?!!!!!!
# 5                    They done made tanjiro like asta
# 6   Just finished the movie, I would\'ve been mad ...
# 7                                                Why?
# 8                         Bro this is gonna be fire 🔥
# 9   THE SONG IS MY FAVORITE THING EVERRRR!!!! 💕💕💕💕...
# 10  This should\'ve been made into a movie This ar...
# 11                             Tengen got dripped out
# 12                                    The OSt men 🔥🔥🔥
# 13                                          L trailer
# 14              When season 4 is come 😅 I can\'t wait
# 15                                  Namu Amida Butsu.
# 16            Its realising on my birthday YEAHHHHHHH
# 17                                                 👍👍
# 18                       Yaaaaaaaaaaaaaaaaaaaaaaaaaa🎉
# 19                                        yey its out
#
#                                                  guid                 to  \
# 0                          UgzLbN7zivs-_vc5hOB4AaABAg                NaN
# 1                          UgxK7GcRTkmmVyXhoX94AaABAg                NaN
# 2                          UgxJDwUKB-DV4-FSsvp4AaABAg                NaN
# 3                          Ugx6roKZSFI2--GNoj14AaABAg                NaN
# 4                          Ugw07D17qa51KT9djeJ4AaABAg                NaN
# 5                          UgykI68cHg-Wt7jw_jl4AaABAg                NaN
# 6                          UgyuEsgMhm-cT_U0U_t4AaABAg                NaN
# 7   UgyuEsgMhm-cT_U0U_t4AaABAg.A2kyaMXieaVA2ly6twfWjm  @TheOneTrueNoName
# 8                          UgxY5w-t86aujwVn5ih4AaABAg                NaN
# 9                          UgzCKO5hq7tD_R5nq0p4AaABAg                NaN
# 10                         UgwLWRoVrTEu2gS15Fl4AaABAg                NaN
# 11                         UgyAocIvCCOmneP0DHV4AaABAg                NaN
# 12                         Ugx11Q1YQvWFM5A95hN4AaABAg                NaN
# 13                         UgzjUgZxWDbD673V2Zx4AaABAg                NaN
# 14                         UgwionjxPdq8r7ZgONZ4AaABAg                NaN
# 15                         Ugy86o5Rlf-01KjTKUF4AaABAg                NaN
# 16                         UgzamKF-IfMjygdaOWl4AaABAg                NaN
# 17                         UgwRp3o46WpDn5hAWcx4AaABAg                NaN
# 18                         UgzecdCCSXSjYyiaovt4AaABAg                NaN
# 19                         UgxGsJ1NdFiUJAt2Z7J4AaABAg                NaN
#
#     likecount                                               link  \
# 0           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 1           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 2           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 3           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 4           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 5           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 6           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 7           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 8           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 9           0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 10          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 11          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 12          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 13          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 14          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 15          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 16          1  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 17          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 18          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
# 19          0  https://www.youtube.com/watch?v=PraFso1sVIc&lc...
#
#                 pubdate  replycount  \
# 0   2024-04-28 11:01:27           0
# 1   2024-04-28 10:16:30           0
# 2   2024-04-28 08:06:03           0
# 3   2024-04-28 06:35:10           0
# 4   2024-04-28 06:33:53           0
# 5   2024-04-27 23:35:51           0
# 6   2024-04-27 22:32:24           1
# 7   2024-04-28 07:47:29           0
# 8   2024-04-27 19:02:56           0
# 9   2024-04-26 18:47:51           0
# 10  2024-04-26 17:53:02           0
# 11  2024-04-26 17:26:16           0
# 12  2024-04-26 09:43:02           0
# 13  2024-04-26 06:09:28           0
# 14  2024-04-26 06:02:40           0
# 15  2024-04-26 04:21:07           0
# 16  2024-04-26 01:07:34           0
# 17  2024-04-26 00:42:43           0
# 18  2024-04-25 23:44:50           0
# 19  2024-04-25 23:08:37           0
#
#                                                 title  \
# 0   I wish this anime never ends until muzan is de...
# 1   Boku no hero academy : where is my Intellectua...
# 2                              I just got crunchyroll
# 3   When I heard Gyomei\'s voice, It\'s always Gin...
# 4                                      Gintoki?!!!!!!
# 5                    They done made tanjiro like asta
# 6   Just finished the movie, I would\'ve been mad ...
# 7                                                Why?
# 8                         Bro this is gonna be fire 🔥
# 9   THE SONG IS MY FAVORITE THING EVERRRR!!!! 💕💕💕💕...
# 10  This should\'ve been made into a movie This ar...
# 11                             Tengen got dripped out
# 12                                    The OSt men 🔥🔥🔥
# 13                                          L trailer
# 14              When season 4 is come 😅 I can\'t wait
# 15                                  Namu Amida Butsu.
# 16            Its realising on my birthday YEAHHHHHHH
# 17                                                 👍👍
# 18                       Yaaaaaaaaaaaaaaaaaaaaaaaaaa🎉
# 19                                        yey its out
#
#                                     authorChannelUrl  Unnamed: 11
# 0           http://www.youtube.com/@sherylhowell3061          NaN
# 1                  http://www.youtube.com/@bsnsj4659          NaN
# 2            http://www.youtube.com/@ThereRobloxgirl          NaN
# 3              http://www.youtube.com/@asphyxia35p21          NaN
# 4              http://www.youtube.com/@asphyxia35p21          NaN
# 5               http://www.youtube.com/@KanarkNights          NaN
# 6           http://www.youtube.com/@TheOneTrueNoName          NaN
# 7            http://www.youtube.com/@imrimenashe5161          NaN
# 8              http://www.youtube.com/@MonicovennSom          NaN
# 9                  http://www.youtube.com/@Freyja369          NaN
# 10    http://www.youtube.com/@anes-for-entertainment          NaN
# 11                      http://www.youtube.com/@DJ0o          NaN
# 12  http://www.youtube.com/@MichaelJohnBesanez-br4gh          NaN
# 13                http://www.youtube.com/@EthanMalde          NaN
# 14           http://www.youtube.com/@user-ew6ks4mu4u          NaN
# 15      http://www.youtube.com/@YORIICHI_TSUGIKUNII7          NaN
# 16                http://www.youtube.com/@sangeetakr          NaN
# 17           http://www.youtube.com/@yasin_arafat_77          NaN
# 18     http://www.youtube.com/@yesseniahernandez9102          NaN
# 19                http://www.youtube.com/@MultiMacel          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2404 non-null   int64
#  1   author            2403 non-null   object
#  2   description       2404 non-null   object
#  3   guid              2404 non-null   object
#  4   to                454 non-null    object
#  5   likecount         2404 non-null   int64
#  6   link              2404 non-null   object
#  7   pubdate           2404 non-null   object
#  8   replycount        2404 non-null   int64
#  9   title             2404 non-null   object
#  10  authorChannelUrl  2404 non-null   object
#  11  Unnamed: 11       0 non-null      float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 225.5+ KB
# None

# %%
import re

def clean_text(text):
    # Remove URLs
    text = re.sub(r'https://www.youtube.com/watch?v=', '..', text)
    text = re.sub(r'[https://www.youtube.com/watch?v=]', '', text)
    # Remove special characters and punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Convert to lowercase
    text = text.lower()
    return text

# %%
# data.drop('pubdate', inplace=True, axis=1)

data.drop('to', inplace=True, axis=1)

# %%
import re

def clean_text(text):
    # Check if the input is a string or NaN, and return an empty string if not
    if isinstance(text, str):
        # Remove URLs
        text = re.sub(r'http\S+', '', text)
        # Remove special characters and punctuation
        text = re.sub(r'[^\w\s]', '', text)
        # Remove numbers
        text = re.sub(r'\d+', '', text)
        # Convert to lowercase
        text = text.lower()
        return text
    else:
        return ""

# Apply the modified clean_text function to the 'description' column
data['description'] = data['description'].apply(clean_text)
data['title'] = data['title'].apply(clean_text)

# %%
data['author'] = data['author'].apply(clean_text)

data['link'] = data['link'].apply(clean_text)

# %%
data['authorChannelUrl'] = data['authorChannelUrl'].apply(clean_text)

# %%
print(data.head(20))
# Out:
#     id                  author  \
# 0    1            sherylhowell
# 1    2                   bsnsj
# 2    3         thererobloxgirl
# 3    4               asphyxiap
# 4    5               asphyxiap
# 5    6            kanarknights
# 6    7        theonetruenoname
# 7    8             imrimenashe
# 8    9           monicovennsom
# 9   10                  freyja
# 10  11    anesforentertainment
# 11  12                     djo
# 12  13  michaeljohnbesanezbrgh
# 13  14              ethanmalde
# 14  15             userewksmuu
# 15  16     yoriichi_tsugikunii
# 16  17              sangeetakr
# 17  18           yasin_arafat_
# 18  19       yesseniahernandez
# 19  20              multimacel
#
#                                           description  \
# 0   i wish this anime never ends until muzan is de...
# 1   boku no hero academy  where is my intellectual...
# 2                              i just got crunchyroll
# 3   when i heard gyomeis voice its always gintoki ...
# 4                                             gintoki
# 5                    they done made tanjiro like asta
# 6   just finished the movie i wouldve been mad as ...
# 7                                                 why
# 8                          bro this is gonna be fire
# 9   the song is my favorite thing everrrr  cant wa...
# 10  this shouldve been made into a movie this arc ...
# 11                             tengen got dripped out
# 12                                       the ost men
# 13                                          l trailer
# 14                  when season  is come  i cant wait
# 15                                   namu amida butsu
# 16            its realising on my birthday yeahhhhhhh
# 17
# 18                        yaaaaaaaaaaaaaaaaaaaaaaaaaa
# 19                                        yey its out
#
#                                                  guid  likecount link  \
# 0                          UgzLbN7zivs-_vc5hOB4AaABAg          0
# 1                          UgxK7GcRTkmmVyXhoX94AaABAg          0
# 2                          UgxJDwUKB-DV4-FSsvp4AaABAg          0
# 3                          Ugx6roKZSFI2--GNoj14AaABAg          0
# 4                          Ugw07D17qa51KT9djeJ4AaABAg          0
# 5                          UgykI68cHg-Wt7jw_jl4AaABAg          0
# 6                          UgyuEsgMhm-cT_U0U_t4AaABAg          0
# 7   UgyuEsgMhm-cT_U0U_t4AaABAg.A2kyaMXieaVA2ly6twfWjm          0
# 8                          UgxY5w-t86aujwVn5ih4AaABAg          0
# 9                          UgzCKO5hq7tD_R5nq0p4AaABAg          0
# 10                         UgwLWRoVrTEu2gS15Fl4AaABAg          0
# 11                         UgyAocIvCCOmneP0DHV4AaABAg          0
# 12                         Ugx11Q1YQvWFM5A95hN4AaABAg          0
# 13                         UgzjUgZxWDbD673V2Zx4AaABAg          0
# 14                         UgwionjxPdq8r7ZgONZ4AaABAg          0
# 15                         Ugy86o5Rlf-01KjTKUF4AaABAg          0
# 16                         UgzamKF-IfMjygdaOWl4AaABAg          1
# 17                         UgwRp3o46WpDn5hAWcx4AaABAg          0
# 18                         UgzecdCCSXSjYyiaovt4AaABAg          0
# 19                         UgxGsJ1NdFiUJAt2Z7J4AaABAg          0
#
#                 pubdate  replycount  \
# 0   2024-04-28 11:01:27           0
# 1   2024-04-28 10:16:30           0
# 2   2024-04-28 08:06:03           0
# 3   2024-04-28 06:35:10           0
# 4   2024-04-28 06:33:53           0
# 5   2024-04-27 23:35:51           0
# 6   2024-04-27 22:32:24           1
# 7   2024-04-28 07:47:29           0
# 8   2024-04-27 19:02:56           0
# 9   2024-04-26 18:47:51           0
# 10  2024-04-26 17:53:02           0
# 11  2024-04-26 17:26:16           0
# 12  2024-04-26 09:43:02           0
# 13  2024-04-26 06:09:28           0
# 14  2024-04-26 06:02:40           0
# 15  2024-04-26 04:21:07           0
# 16  2024-04-26 01:07:34           0
# 17  2024-04-26 00:42:43           0
# 18  2024-04-25 23:44:50           0
# 19  2024-04-25 23:08:37           0
#
#                                                 title authorChannelUrl  \
# 0   i wish this anime never ends until muzan is de...
# 1   boku no hero academy  where is my intellectual...
# 2                              i just got crunchyroll
# 3   when i heard gyomeis voice its always gintoki ...
# 4                                             gintoki
# 5                    they done made tanjiro like asta
# 6   just finished the movie i wouldve been mad as ...
# 7                                                 why
# 8                          bro this is gonna be fire
# 9   the song is my favorite thing everrrr  cant wa...
# 10  this shouldve been made into a movie this arc ...
# 11                             tengen got dripped out
# 12                                       the ost men
# 13                                          l trailer
# 14                  when season  is come  i cant wait
# 15                                   namu amida butsu
# 16            its realising on my birthday yeahhhhhhh
# 17
# 18                        yaaaaaaaaaaaaaaaaaaaaaaaaaa
# 19                                        yey its out
#
#     Unnamed: 11
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2404 non-null   int64
#  1   author            2404 non-null   object
#  2   description       2404 non-null   object
#  3   guid              2404 non-null   object
#  4   likecount         2404 non-null   int64
#  5   link              2404 non-null   object
#  6   pubdate           2404 non-null   object
#  7   replycount        2404 non-null   int64
#  8   title             2404 non-null   object
#  9   authorChannelUrl  2404 non-null   object
#  10  Unnamed: 11       0 non-null      float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 206.7+ KB
# None
